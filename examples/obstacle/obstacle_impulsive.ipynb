# %%
import logging

import numpy as np
import matplotlib.pyplot as plt

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s %(levelname)s %(name)-40s :: %(message)s'
)

# %% [markdown]
# # Inverse Obstacle problem corrupted by impulsive noise
#
# Operator that maps the shape of a sound-soft obstacle to the far-field measurements.
# The scattering problem is described by
#
# $$
#         \begin{cases}
#             \Delta u +\kappa^2 u = 0 & \text{ in } \mathbb{R}^2\backslash\overline{D}\\
#              u = 0  & \text{ on } \partial D\\
#             \displaystyle{\lim_{r\to\infty}}r^{\frac{1}{2}}(\frac{\partial u^s}{\partial r}-i\kappa u^s)=0 & \text{ for } r=|x|,
#         \end{cases}
# $$
# where $u=u^s+u^i$ is the total field and $D$ is a bounded obstacle in $\mathbb{R}^2$ with $\partial D\in\mathcal{C}^2$.
#
# Here we assume that only the imaginary part of the far field pattern of $u^s$ can be measured, which is relevant in passive imaging.

# %%
from  dirichlet_op import DirichletOp
from regpy.operators import ImaginaryPart

#Forward operator
op0 = DirichletOp(
    kappa = 3,
    N_inc=4
)
op = ImaginaryPart(op0.codomain) * op0

# %% [markdown]
# ## generate synthetic data with impulsive noise

# %%
from regpy.solvers import RegularizationSetting
from regpy.hilbert import L2, Sobolev
from dirichlet_op import create_synthetic_data

#Exact data
farfield, exact_solution = create_synthetic_data(op0, true_curve='apple')
im_farfield = farfield.imag

#Impulsive noise
data = im_farfield.copy()
n,m = data.shape
for i in range(m):
    for j in range(5):
        k = np.random.randint(len(farfield))
        data[k,i] = np.random.randint(10)-5
        #data[k,i] = complex(np.random.randint(10)-5,np.random.randint(10)-5)

#Initial guess
t = 2*np.pi*np.arange(0, op0.N_FK)/op0.N_FK
init = 0.45*np.append(np.cos(t), np.sin(t)).reshape((2, op0.N_FK))
init=init.flatten()

ax = plt.plot(op.codomain.coords[0],data[:,2],label='Im u_{\infty}')

# %% [markdown]
# ## Standard approach
# First we try what happens if we apply a standard IRGNM solver.

# %%
from regpy.solvers.nonlinear.irgnm import IrgnmCG
from regpy.solvers.nonlinear.newton import NewtonCG
import regpy.stoprules as rules

L2setting = RegularizationSetting(op=op, penalty=Sobolev, data_fid=L2)

#Solver: NewtonCG or IrgnmCG
solver = IrgnmCG(L2setting, data, regpar=10, init = init)

stoprule = (
    rules.CountIterations(10) 
)

#Plot function
fig, axs = plt.subplots(1, 2)
axs[0].set_title('Obstacle')
axs[1].set_title('Farfield (real part)')

reco, reco_data = solver.run(stoprule)
axs[0].plot(*exact_solution.z)
axs[0].plot(*op.domain.bd_eval(reco, nvals=op0.N_ieq, nderivs=3).z)

axs[1].plot(op.codomain.coords[0][:,0], im_farfield[:,0], label='exact')
axs[1].plot(op.codomain.coords[0][:,0], reco_data[:,0], label='reco')
axs[1].plot(op.codomain.coords[0][:,0], data[:,0], label='measured')
axs[1].legend()
plt.show()
# Out:
# 2024-06-27 15:00:11,344 INFO CountIterations                          :: iteration = 1 / 10
# 2024-06-27 15:00:11,534 INFO IrgnmCG                                  :: its.1: alpha=6.666666666666666, CG its:2
# 2024-06-27 15:00:11,536 INFO CountIterations                          :: iteration = 2 / 10
# 2024-06-27 15:00:11,738 INFO IrgnmCG                                  :: its.2: alpha=4.444444444444444, CG its:3
# 2024-06-27 15:00:11,739 INFO CountIterations                          :: iteration = 3 / 10
# 2024-06-27 15:00:11,994 INFO IrgnmCG                                  :: its.3: alpha=2.9629629629629624, CG its:4
# 2024-06-27 15:00:11,995 INFO CountIterations                          :: iteration = 4 / 10
# 2024-06-27 15:00:12,333 INFO IrgnmCG                                  :: its.4: alpha=1.975308641975308, CG its:4
# 2024-06-27 15:00:12,334 INFO CountIterations                          :: iteration = 5 / 10
# 2024-06-27 15:00:12,647 INFO IrgnmCG                                  :: its.5: alpha=1.3168724279835387, CG its:4
# 2024-06-27 15:00:12,648 INFO CountIterations                          :: iteration = 6 / 10
# 2024-06-27 15:00:12,934 INFO IrgnmCG                                  :: its.6: alpha=0.8779149519890257, CG its:4
# 2024-06-27 15:00:12,936 INFO CountIterations                          :: iteration = 7 / 10
# 2024-06-27 15:00:13,381 INFO IrgnmCG                                  :: its.7: alpha=0.5852766346593504, CG its:6
# 2024-06-27 15:00:13,382 INFO CountIterations                          :: iteration = 8 / 10
# 2024-06-27 15:00:13,701 INFO IrgnmCG                                  :: its.8: alpha=0.3901844231062336, CG its:5
# 2024-06-27 15:00:13,703 INFO CountIterations                          :: iteration = 9 / 10
# 2024-06-27 15:00:14,997 INFO IrgnmCG                                  :: its.9: alpha=0.26012294873748903, CG its:22
# 2024-06-27 15:00:14,997 INFO CountIterations                          :: iteration = 10 / 10
# 2024-06-27 15:00:42,521 INFO IrgnmCG                                  :: its.10: alpha=0.17341529915832601, CG its:415
# 2024-06-27 15:00:42,523 INFO IrgnmCG                                  :: Solver converged after 10 iteration.

# %% [markdown]
# ## Reconstruction with Huber data fidelity term
#
# Now introduce a Huber data fidelity term $H_{\sigma}$ ...

# %%
from regpy.solvers import TikhonovRegularizationSetting
from regpy.solvers.linear.semismoothNewton import SemismoothNewton_bilateral
from regpy.functionals import Huber,HorizontalShiftDilation

alpha = 10.
sigma = 0.1
Sdat = (1./sigma)*Huber(op.codomain,sigma=sigma)

fk = init

# %% [markdown]
# ... and iteratively solve
# $$
#     f^{l+1}  \in \mathrm{argmin}_f \left[\frac{1}{\alpha_l}H_{\sigma}(F'[f^l](f-f^l) + F(f^l) -g^{\mathrm{obs}}+ \|f-f_0\|^2\right]
# $$
#
# Run the following cell many times to see the reconstructions improving!

# %%
yk,deriv = op.linearize(fk)
huber_setting = TikhonovRegularizationSetting(deriv,Sobolev,Sdat,alpha,data_fid_shift=data-yk)
dual_setting = huber_setting.dualSetting()
solver = SemismoothNewton_bilateral(dual_setting)
_,Tstar_p = solver.run(stoprule=rules.CountIterations(50))
update = huber_setting.dualToPrimal(Tstar_p,argumentIsOperatorImage=True)
fk+= update
alpha *=0.5

plt.plot(*exact_solution.z)
plt.plot(*op.domain.bd_eval(fk, nvals=op0.N_ieq, nderivs=3).z)
# Out:
# 2024-06-27 15:01:30,239 INFO TikhonovCG                               :: it.24 kappa=1.0100218118097362 err/Tol abs X: 6.3e-04/2.8e-03
# 2024-06-27 15:01:30,240 INFO TikhonovCG                               :: Solver converged after 24 iteration.
# 2024-06-27 15:01:30,242 INFO CountIterations                          :: iteration = 1 / 50
# 2024-06-27 15:01:30,459 INFO TikhonovCG                               :: it.2 kappa=1.0 err/Tol abs X: 6.3e-16/2.8e-03
# 2024-06-27 15:01:30,459 INFO TikhonovCG                               :: Solver converged after 2 iteration.
# 2024-06-27 15:01:30,514 INFO SemismoothNewton_bilateral               :: it 1: CG its 2, changes active sets +2,-171
# 2024-06-27 15:01:30,516 INFO CountIterations                          :: iteration = 2 / 50
# 2024-06-27 15:01:31,781 INFO TikhonovCG                               :: it.24 kappa=1.0055663829772048 err/Tol abs X: 2.5e-04/2.8e-03
# 2024-06-27 15:01:31,782 INFO TikhonovCG                               :: Solver converged after 24 iteration.
# 2024-06-27 15:01:31,844 INFO SemismoothNewton_bilateral               :: it 2: CG its 24, changes active sets +149,-56
# 2024-06-27 15:01:31,845 INFO CountIterations                          :: iteration = 3 / 50
# 2024-06-27 15:01:33,704 INFO TikhonovCG                               :: it.19 kappa=1.0102480011729305 err/Tol abs X: 3.2e-04/2.8e-03
# 2024-06-27 15:01:33,705 INFO TikhonovCG                               :: Solver converged after 19 iteration.
# 2024-06-27 15:01:33,794 INFO SemismoothNewton_bilateral               :: it 3: CG its 19, changes active sets +66,-135
# 2024-06-27 15:01:33,796 INFO CountIterations                          :: iteration = 4 / 50
# 2024-06-27 15:01:35,008 INFO TikhonovCG                               :: it.19 kappa=1.3213388506420056 err/Tol abs X: 1.4e-03/2.8e-03
# 2024-06-27 15:01:35,009 INFO TikhonovCG                               :: Solver converged after 19 iteration.
# 2024-06-27 15:01:35,077 INFO SemismoothNewton_bilateral               :: it 4: CG its 19, changes active sets +0,-89
# 2024-06-27 15:01:35,078 INFO CountIterations                          :: iteration = 5 / 50
# 2024-06-27 15:01:36,729 INFO TikhonovCG                               :: it.19 kappa=1.0769585321609418 err/Tol abs X: 1.0e-03/2.8e-03
# 2024-06-27 15:01:36,730 INFO TikhonovCG                               :: Solver converged after 19 iteration.
# 2024-06-27 15:01:36,842 INFO SemismoothNewton_bilateral               :: it 5: CG its 19, changes active sets +0,-0
# 2024-06-27 15:01:36,842 INFO CountIterations                          :: iteration = 6 / 50
# 2024-06-27 15:01:36,845 INFO SemismoothNewton_bilateral               :: Solver converged after 5 iteration.
