# %% [markdown]
# This is an example for the `regpy.solvers.nonlinear.irgnm.IrgnmCG` solver for the example of __X-ray phase retriavel__.
#
# In X-ray phase retrieval, we assume that a coherent plain wave hits a shallow monomaterial object that absorbs part of the beam intensity and phase shifts the rest, depending on the density of material. The ratio of shifting and abortion is given by $\beta/\delta$. The wave the propagates behind the object and then the intensity of the wave (hologram) is measured at some point.  The phase information is lost and needs to be recovered.
#
# The forward operator $F$ of X-ray phase contrast imaging is defined by
#
# $$
#     F(\phi) = |D_F(exp(-(i + c_{\beta/\delta}) \cdot  phi))|^2 = I
# $$
#
# where $D_F$ is the Fresnel-propagator and $c_{\beta/\delta}$ is
# a constant that parametrizes the magnitude of X-ray absorption versus X-ray
# refraction for the imaged sample ( $c_{\beta/\delta} = \beta/\delta$).
#
# [![image.png](attachment:image.png)](https://ediss.uni-goettingen.de/handle/21.11130/00-1735-0000-0003-C12B-3)
# The image is from the [phd thesis of Simon Maretzke (2019)](https://ediss.uni-goettingen.de/handle/21.11130/00-1735-0000-0003-C12B-3)
#
# The __Iteratively Regularized Gauss-Newton Method method__ minimizes in each iteration:
# $$
#     \Vert(x_{n}) + T'[x_n] h - data\Vert^{2} + regpar_{n} \cdot \Vert x_{n} + h - init\Vert^{2}
# $$
# where $T$ is a Frechet-differentiable operator, using `regpy.solvers.linear.tikhonov.TikhonovCG`.
# $regpar_n$ is a decreasing geometric sequence of regularization parameters.

# %%
from regpy.solvers.nonlinear.irgnm import IrgnmCG

from regpy.operators.fresnel import get_xray_phase_contrast
from regpy.hilbert import L2
from regpy.vecsps import UniformGridFcts
from regpy.solvers import HilbertSpaceSetting
import regpy.stoprules as rules

import numpy as np
from scipy.datasets import ascent
import logging
import matplotlib.pyplot as plt

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s %(levelname)s %(name)-20s :: %(message)s'
)

# %% [markdown]
# We first have to define the forward propagation operator for that we have to define a grid and a fresnel number, which is encoding the propagation distance

# %%
# Example parameters
fresnel_number = 5e-4    # Fresnel-number of the simulated imaging system, associated with the unit-lengthscale
                         # in grid (i.e. with the size of one pixel for the above choice of grid)
noise_level = 0.01      # Noise level in the simulated data

# %%
# Uniform grid of unit-spacing
grid = UniformGridFcts(np.arange(1024), np.arange(1024))

# Forward operator
op = xray_phase_contrast(grid, fresnel_number)

# %% [markdown]
# We build our simulated data using the ascent image in the scipy library

# %%
# Create phantom phase-image (= padded example-image)
exact_solution = ascent().astype(np.float64)
#normalizing the image
exact_solution /= exact_solution.max()
#The wave needs to propagated and for that some room around the signal is necessary there for we add padding
pad_amount = tuple([(grid.shape[0] - exact_solution.shape[0])//2,
                    (grid.shape[1] - exact_solution.shape[1])//2])
exact_solution = np.pad(exact_solution, pad_amount, 'constant', constant_values=0)



fig,axs = plt.subplots(1,2,figsize=(12,5))
ax = axs[0]
im = ax.imshow(ascent().astype(np.float64))
ax.set_title("scipy ascent image")
plt.colorbar(im,ax=ax)
ax = axs[1]
im = plt.imshow(exact_solution)
ax.set_title("scaled and paded")
plt.colorbar(im,ax=ax)

# %%
# Create exact and noisy data
exact_data = op(exact_solution)
noise = noise_level * op.codomain.randn()
data = exact_data + noise
fig,axs = plt.subplots(1,2,figsize=(12,5))
ax = axs[0]
im = ax.imshow(exact_data)
ax.set_title("exact data")
plt.colorbar(im,ax=ax)
ax = axs[1]
im = plt.imshow(data)
ax.set_title(f"datawith {noise_level} noise")
plt.colorbar(im,ax=ax)

# %% [markdown]
# We then can __set up__ the __solver__ `regpy.solvers.nonlinear.irgnm.IrgnmCG` by building a __setting__ using the operator and the `L2` spaces, which we then give into the solver together with the __`data`__ and a regularization parameter __`regpar`__

# %%
# Image-reconstruction using the IRGNM method
#define setting with operator and its domain and co-domain
setting = HilbertSpaceSetting(op=op, h_domain=L2, h_codomain=L2)
#Setup the solver
solver = IrgnmCG(setting, data, regpar=10)

# %% [markdown]
# We also need to define a stopping rule here we combine a maximum amount of iterations and the discrepancy principle (for more see `regpy.stoprules.rules`).

# %%
#define the stoprule from maximum amount of iterations and discrepancy principle
stoprule = (
    rules.CountIterations(max_iterations=30) +
    rules.Discrepancy(
        setting.h_codomain.norm,
        data,
        noiselevel=setting.h_codomain.norm(noise),
        tau=1.1
    )
)

# %% [markdown]
# We now can run the solver.

# %%
#run the solver with stopping rule
reco, reco_data = solver.run(stoprule)
# Out:
# 2024-03-25 10:44:59,919 INFO CountIterations      :: iteration = 0 / 30
# 2024-03-25 10:44:59,931 INFO Discrepancy          :: relative discrepancy = 12.70, tolerance = 1.10
# 2024-03-25 10:45:00,256 INFO TikhonovCG           :: it.1 err/Tol X:8.7e-02/2.3e-01
# 2024-03-25 10:45:00,257 INFO TikhonovCG           :: Solver converged after 1 iteration.
# 2024-03-25 10:45:00,347 INFO CountIterations      :: iteration = 1 / 30
# 2024-03-25 10:45:00,356 INFO Discrepancy          :: relative discrepancy = 10.26, tolerance = 1.10
# 2024-03-25 10:45:00,647 INFO TikhonovCG           :: it.1 err/Tol X:1.6e-01/2.3e-01
# 2024-03-25 10:45:00,647 INFO TikhonovCG           :: Solver converged after 1 iteration.
# 2024-03-25 10:45:00,741 INFO CountIterations      :: iteration = 2 / 30
# 2024-03-25 10:45:00,749 INFO Discrepancy          :: relative discrepancy = 9.37, tolerance = 1.10
# 2024-03-25 10:45:01,263 INFO TikhonovCG           :: it.2 err/Tol X:3.5e-02/2.3e-01
# 2024-03-25 10:45:01,264 INFO TikhonovCG           :: Solver converged after 2 iteration.
# 2024-03-25 10:45:01,363 INFO CountIterations      :: iteration = 3 / 30
# 2024-03-25 10:45:01,374 INFO Discrepancy          :: relative discrepancy = 8.40, tolerance = 1.10
# 2024-03-25 10:45:01,970 INFO TikhonovCG           :: it.2 err/Tol X:6.8e-02/2.3e-01
# 2024-03-25 10:45:01,971 INFO TikhonovCG           :: Solver converged after 2 iteration.
# 2024-03-25 10:45:02,071 INFO CountIterations      :: iteration = 4 / 30
# 2024-03-25 10:45:02,083 INFO Discrepancy          :: relative discrepancy = 7.34, tolerance = 1.10
# 2024-03-25 10:45:02,608 INFO TikhonovCG           :: it.2 err/Tol X:1.4e-01/2.3e-01
# 2024-03-25 10:45:02,608 INFO TikhonovCG           :: Solver converged after 2 iteration.
# 2024-03-25 10:45:02,701 INFO CountIterations      :: iteration = 5 / 30
# 2024-03-25 10:45:02,714 INFO Discrepancy          :: relative discrepancy = 6.27, tolerance = 1.10
# 2024-03-25 10:45:03,295 INFO TikhonovCG           :: it.2 err/Tol X:2.5e-01/2.3e-01 Y:2.0e-01/2.3e-01
# 2024-03-25 10:45:03,295 INFO TikhonovCG           :: Solver converged after 2 iteration.
# 2024-03-25 10:45:03,385 INFO CountIterations      :: iteration = 6 / 30
# 2024-03-25 10:45:03,398 INFO Discrepancy          :: relative discrepancy = 5.26, tolerance = 1.10
# 2024-03-25 10:45:04,171 INFO TikhonovCG           :: it.3 err/Tol X:1.9e-01/2.3e-01
# 2024-03-25 10:45:04,171 INFO TikhonovCG           :: Solver converged after 3 iteration.
# 2024-03-25 10:45:04,266 INFO CountIterations      :: iteration = 7 / 30
# 2024-03-25 10:45:04,280 INFO Discrepancy          :: relative discrepancy = 4.34, tolerance = 1.10
# 2024-03-25 10:45:05,095 INFO TikhonovCG           :: it.3 err/Tol X:3.3e-01/2.3e-01 Y:2.2e-01/2.3e-01
# 2024-03-25 10:45:05,096 INFO TikhonovCG           :: Solver converged after 3 iteration.
# 2024-03-25 10:45:05,192 INFO CountIterations      :: iteration = 8 / 30
# 2024-03-25 10:45:05,210 INFO Discrepancy          :: relative discrepancy = 3.55, tolerance = 1.10
# 2024-03-25 10:45:06,347 INFO TikhonovCG           :: it.4 err/Tol X:3.1e-01/2.3e-01 Y:2.1e-01/2.3e-01
# 2024-03-25 10:45:06,348 INFO TikhonovCG           :: Solver converged after 4 iteration.
# 2024-03-25 10:45:06,446 INFO CountIterations      :: iteration = 9 / 30
# 2024-03-25 10:45:06,460 INFO Discrepancy          :: relative discrepancy = 2.89, tolerance = 1.10
# 2024-03-25 10:45:07,786 INFO TikhonovCG           :: it.5 err/Tol X:3.6e-01/2.3e-01 Y:2.3e-01/2.3e-01
# 2024-03-25 10:45:07,786 INFO TikhonovCG           :: Solver converged after 5 iteration.
# 2024-03-25 10:45:07,893 INFO CountIterations      :: iteration = 10 / 30
# 2024-03-25 10:45:07,903 INFO Discrepancy          :: relative discrepancy = 2.35, tolerance = 1.10
# 2024-03-25 10:45:09,541 INFO TikhonovCG           :: it.7 err/Tol X:2.6e-01/2.3e-01 Y:1.7e-01/2.3e-01
# 2024-03-25 10:45:09,542 INFO TikhonovCG           :: Solver converged after 7 iteration.
# 2024-03-25 10:45:09,633 INFO CountIterations      :: iteration = 11 / 30
# 2024-03-25 10:45:09,648 INFO Discrepancy          :: relative discrepancy = 1.91, tolerance = 1.10
# 2024-03-25 10:45:11,477 INFO TikhonovCG           :: it.8 err/Tol X:3.3e-01/2.3e-01 Y:2.1e-01/2.3e-01
# 2024-03-25 10:45:11,478 INFO TikhonovCG           :: Solver converged after 8 iteration.
# 2024-03-25 10:45:11,572 INFO CountIterations      :: iteration = 12 / 30
# 2024-03-25 10:45:11,580 INFO Discrepancy          :: relative discrepancy = 1.55, tolerance = 1.10
# 2024-03-25 10:45:13,746 INFO TikhonovCG           :: it.10 err/Tol X:3.1e-01/2.3e-01 Y:2.0e-01/2.3e-01
# 2024-03-25 10:45:13,746 INFO TikhonovCG           :: Solver converged after 10 iteration.
# 2024-03-25 10:45:13,871 INFO CountIterations      :: iteration = 13 / 30
# 2024-03-25 10:45:13,880 INFO Discrepancy          :: relative discrepancy = 1.26, tolerance = 1.10
# 2024-03-25 10:45:16,558 INFO TikhonovCG           :: it.12 err/Tol X:3.5e-01/2.3e-01 Y:2.2e-01/2.3e-01
# 2024-03-25 10:45:16,559 INFO TikhonovCG           :: Solver converged after 12 iteration.
# 2024-03-25 10:45:16,646 INFO CountIterations      :: iteration = 14 / 30
# 2024-03-25 10:45:16,654 INFO Discrepancy          :: relative discrepancy = 1.03, tolerance = 1.10
# 2024-03-25 10:45:16,655 INFO CombineRules         :: Rule Discrepancy(noiselevel=10.242523921209044, tau=1.1) triggered.
# 2024-03-25 10:45:16,655 INFO IrgnmCG              :: Solver converged after 14 iteration.

# %%
# Plot results
fig,axs = plt.subplots(1,3,figsize = (20,5))
ax = axs[0]
ax.set_title('Simulated data (hologram)')
im = ax.imshow(data)
fig.colorbar(im,ax=ax)

ax = axs[1]
ax.set_title('Reconstruction (phase-image)')
im = ax.imshow(reco)
fig.colorbar(im,ax=ax)

ax = axs[2]
ax.set_title('Exact solution (phase-image)')
im = ax.imshow(exact_solution)
fig.colorbar(im,ax = ax)

plt.show()
